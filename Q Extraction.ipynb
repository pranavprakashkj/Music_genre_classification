# %% [markdown]
# # Q Transform spectogram

# %%
import matplotlib.pyplot as plt

from librosa.display import specshow
import librosa

from scipy.io import wavfile
import numpy as np

# %% [markdown]
# ### Reading the file and plotting

# %%
freq, data = wavfile.read('disco.00000.wav')
print('Sampling frequency:', freq)

data = data.astype(float)

plt.title('Waveform')
plt.plot(data)
plt.show()
# Out:
# Sampling frequency: 22050

# %% [markdown]
# ### Plotting the spectogram(STFT)

# %%
D = librosa.amplitude_to_db(librosa.stft(data, hop_length=128), ref=np.max)
librosa.display.specshow(D, y_axis='linear', sr=freq, hop_length=128, bins_per_octave=24)
plt.colorbar(format='%+2.0f dB')
plt.title('Linear-frequency power spectrogram')
plt.show()
# Out:
# E:\anaconda3\lib\site-packages\librosa\core\spectrum.py:1641: UserWarning: amplitude_to_db was called on complex input so phase information will be discarded. To suppress this warning, call amplitude_to_db(np.abs(S)) instead.
#   warnings.warn(

# %%
librosa.display.specshow(D, y_axis='log', sr=freq, hop_length=128, bins_per_octave=24)
plt.colorbar(format='%+2.0f dB')
plt.title('Log-frequency power spectrogram')
plt.show()

# %% [markdown]
# ### plot Q Transform spectrum

# %%
CQT = librosa.amplitude_to_db(librosa.cqt(data, sr=freq, hop_length=128), ref=np.max)
librosa.display.specshow(CQT, y_axis='cqt_hz', hop_length=128)
plt.colorbar(format='%+2.0f dB')
plt.title('Constant-Q power spectrogram (Hz)')
plt.show()
# Out:
# E:\anaconda3\lib\site-packages\librosa\core\spectrum.py:1641: UserWarning: amplitude_to_db was called on complex input so phase information will be discarded. To suppress this warning, call amplitude_to_db(np.abs(S)) instead.
#   warnings.warn(
